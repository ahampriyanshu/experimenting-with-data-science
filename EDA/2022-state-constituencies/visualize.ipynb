# %% [markdown]
# # EDA of Uttar Pradesh 2022
#
# * [myneta.info](https://myneta.info/)

# %% [markdown]
# ## Visualizing data

# %%
import pandas as pd
import numpy as np
import matplotlib

# %matplotlib inline

matplotlib.rc('figure', figsize=(10, 5))
matplotlib.rc('font', weight='bold', size=12)

# %%
data = pd.read_csv('up.csv')
data
# Out:
#                  Candidate                 Party  Criminal Cases  \
# 0                 Ali Khan                   IND               1
# 1         Dharam Pal Singh                   IND               0
# 2                Mo. Ikram                   IND               0
# 3             Naresh Saini                   BJP               0
# 4            Poonam Kamboj                   INC               0
# ...                    ...                   ...             ...
# 4401   Manoj Kumar Chaubey                   IND               2
# 4402      Neel Ratan Singh                   BJP               2
# 4403               Santosh  Moulik Adhikar Party               0
# 4404              Surendra     Jan Adhikar Party               2
# 4405  Surendra Singh Patel                    SP               1
#
#           Education  Age         Constituency  Total Assets  Liabilities
# 0         10th Pass   31   Behat + Saharanpur      23542241            0
# 1          Graduate   46   Behat + Saharanpur       5565000            0
# 2          5th Pass   47   Behat + Saharanpur       2481845       200000
# 3     Post Graduate   57   Behat + Saharanpur      29506003      5779181
# 4     Post Graduate   36   Behat + Saharanpur      13552777      1800000
# ...             ...  ...                  ...           ...          ...
# 4401  Post Graduate   42  Sevapuri + Varanasi       2172346            0
# 4402      12th Pass   50  Sevapuri + Varanasi      19373958            0
# 4403      12th Pass   51  Sevapuri + Varanasi      12149100       258000
# 4404       Graduate   44  Sevapuri + Varanasi      24450000      1500000
# 4405       Literate   64  Sevapuri + Varanasi      41732708      1139699
#
# [4406 rows x 8 columns]

# %%
data.describe()
# Out:
#        Criminal Cases          Age  Total Assets   Liabilities
# count     4406.000000  4406.000000  4.406000e+03  4.406000e+03
# mean         0.761008    45.750113  2.871756e+07  2.466444e+06
# std          2.618772    11.525502  9.350072e+07  1.156151e+07
# min          0.000000    25.000000  0.000000e+00  0.000000e+00
# 25%          0.000000    37.000000  1.171153e+06  0.000000e+00
# 50%          0.000000    45.000000  5.553000e+06  0.000000e+00
# 75%          1.000000    53.000000  2.232900e+07  8.110000e+05
# max         87.000000    92.000000  2.968849e+09  3.012381e+08

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4406 entries, 0 to 4405
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Candidate       4406 non-null   object
#  1   Party           4406 non-null   object
#  2   Criminal Cases  4406 non-null   int64
#  3   Education       4406 non-null   object
#  4   Age             4406 non-null   int64
#  5   Constituency    4406 non-null   object
#  6   Total Assets    4406 non-null   int64
#  7   Liabilities     4406 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 275.5+ KB

# %%
# Total number of Parties
np.size(data["Party"].unique()) - 1
# Reducing by one for independent candidates
# Out:
# 285

# %%
candidates = np.size(data["Candidate"])
candidates
# Out:
# 4406

# %%
candidates - np.size(data["Candidate"].unique())
# Out:
# 703

# %%
candidates - data.groupby(['Candidate', 'Party']).ngroups
# Out:
# 161

# %%
candidates - data.groupby(['Candidate', 'Constituency']).ngroups
# Out:
# 10

# %%
data.groupby(['Candidate', 'Education'])['Total Assets'].sum().sort_values(ascending=False).head(25)
# Out:
# Candidate                  Education
# Nawab Kazim Ali Khan       Post Graduate            2968848840
# Shah Alam (Guddu Jamali)   Post Graduate            1958570465
# Supriya Aron               Post Graduate            1573049919
# Amit Agarwal               Graduate Professional    1487664557
# Devender Nagpal            Graduate                 1407648765
# S.K.Sharma                 12th Pass                1122970707
# Rahul Yadav                Others                   1006302500
# Kunal Singh                Graduate Professional     880892909
# Sahender Singh Ramala      10th Pass                 845070499
# Rais Ahmad                 Graduate                  730221928
# Yashpal Singh Yadav        Post Graduate             707404691
# Ajay Kapoor                Graduate                  694617271
# Vinay Shankar              Graduate Professional     675228964
# Rakesh Pandey              8th Pass                  634647716
# Kartar Singh Bhadana       8th Pass                  608746125
# Mohd Nasir                 Literate                  606821671
# Rani Pakshalika Singh      Graduate                  584850043
# Mayankeshwar Sharan Singh  Graduate                  580703047
# Rajiv Bakshi               Post Graduate             566207026
# Umashankar Singh           12th Pass                 540504522
# Anoop Kumar Gupta          Graduate                  523943856
# Sindhuja Mishra Senani     Post Graduate             522036165
# Dr.Sanjay Singh            Doctorate                 504828241
# Raja Bharatendra Singh     Graduate                  486025676
# Ajay Kumar Singh           Graduate Professional     485468075
# Name: Total Assets, dtype: int64

# %%
data.groupby(['Candidate', 'Education'])['Liabilities'].sum().sort_values(ascending=False).head(25)
# Out:
# Candidate                          Education
# Kunal Singh                        Graduate Professional    301238121
# Rakesh Pandey                      8th Pass                 232288591
# Devender Nagpal                    Graduate                 214852017
# Dr. Raj Kumar Singh Gautam         Doctorate                174701582
# Shahana Siddiqui                   8th Pass                 172943000
# Yashpal Singh Yadav                Post Graduate            133863643
# Amit Agarwal                       Graduate Professional    132973889
# Umashankar Singh                   12th Pass                130235095
# Vikas Gupta                        Post Graduate            123191949
# Omkumar                            12th Pass                121649591
# Sahender Singh Ramala              10th Pass                111385036
# Subhash Passi                      10th Pass                101500000
# Rajesh Kumar                       Post Graduate            101071878
# Ajay Kapoor                        Graduate                  99354343
# S.K.Sharma                         12th Pass                 98821091
# Sanjay Goswami                     12th Pass                 96227230
# Mukesh Srivastava                  12th Pass                 87187741
# Basant Chaudhary                   8th Pass                  86699219
# Rakesh Sachan                      Post Graduate             81778692
# Baqaullah                          Graduate Professional     79447133
# Dr. Jitendra Singh Yadav           Graduate Professional     79365614
# Sidharth Nath Singh                Graduate                  76035288
# Deep Narayan Singh (Deepak Yadav)  Graduate                  70588698
# Rais Ahmad                         Graduate                  67339542
# Armaan Khan                        Graduate                  67103174
# Name: Liabilities, dtype: int64

# %%
party_data = data[data["Party"].isin(["AAP","AIMIM","BSP","BJP","INC","IND","SP","JDU","RLD"])]
party_data.reset_index()
party_data
# Out:
#                   Candidate Party  Criminal Cases              Education  Age  \
# 0                  Ali Khan   IND               1              10th Pass   31
# 1          Dharam Pal Singh   IND               0               Graduate   46
# 2                 Mo. Ikram   IND               0               5th Pass   47
# 3              Naresh Saini   BJP               0          Post Graduate   57
# 4             Poonam Kamboj   INC               0          Post Graduate   36
# ...                     ...   ...             ...                    ...  ...
# 4397  Arvind Kumar Tripathi   BSP               0  Graduate Professional   54
# 4400          Kailash Patel   AAP               1              12th Pass   57
# 4401    Manoj Kumar Chaubey   IND               2          Post Graduate   42
# 4402       Neel Ratan Singh   BJP               2              12th Pass   50
# 4405   Surendra Singh Patel    SP               1               Literate   64
#
#              Constituency  Total Assets  Liabilities
# 0      Behat + Saharanpur      23542241            0
# 1      Behat + Saharanpur       5565000            0
# 2      Behat + Saharanpur       2481845       200000
# 3      Behat + Saharanpur      29506003      5779181
# 4      Behat + Saharanpur      13552777      1800000
# ...                   ...           ...          ...
# 4397  Sevapuri + Varanasi      85557041     14356147
# 4400  Sevapuri + Varanasi      26566854            0
# 4401  Sevapuri + Varanasi       2172346            0
# 4402  Sevapuri + Varanasi      19373958            0
# 4405  Sevapuri + Varanasi      41732708      1139699
#
# [2905 rows x 8 columns]

# %%
party_sorted = party_data[["Party","Candidate"]].groupby(["Party"]).aggregate(lambda x: len(x.unique())).sort_values(["Candidate"], ascending = False )
party_sorteds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 2>()
#       1 party_sorted = party_data[["Party","Candidate"]].groupby(["Party"]).aggregate(lambda x: len(x.unique())).sort_values(["Candidate"], ascending = False )
# ----> 2 party_sorteds
#
# NameError: name 'party_sorteds' is not defined

# %%
party_sorted.plot(kind="bar")

# %%
ed_data = pd.pivot_table(data,values=["Candidate"],aggfunc=lambda x: len(x.unique()), index=["Education"]).sort_values(["Candidate"], ascending = False )
ed_data.reset_index()
ed_data.plot(kind="bar")

# %%
ed_party_data = pd.pivot_table(party_data, values=["Candidate"],aggfunc=lambda x: len(x.unique()), index=["Education"], columns=["Party"])
ed_party_data.fillna(0)

# %%
criminal_data_asc = data[["Candidate","Constituency","Party", "Education","Criminal Cases"]].sort_values('Criminal Cases', ascending=False).head(25)
criminal_data_asc = criminal_data_asc.reset_index(drop=True)
criminal_data_asc

# %%
criminal_data_dsc = data[["Candidate","Constituency","Party", "Education","Criminal Cases"]].sort_values('Criminal Cases', ascending=True).head(25)
criminal_data_dsc = criminal_data_dsc.reset_index(drop=True)
criminal_data_dsc
# Out:
#                   Candidate             Constituency  \
# 0                Ramkhiladi        Gunnaur + Sambhal
# 1            Ravindra Kumar      Madhaugarh + Jalaun
# 2          Sheetal Kushwaha      Madhaugarh + Jalaun
# 3          Siddarth Devolia      Madhaugarh + Jalaun
# 4               Suresh Babu      Madhaugarh + Jalaun
# 5      Ainul Hasan Mansoori           Kalpi + Jalaun
# 6               Anjana Devi           Kalpi + Jalaun
# 7             Santosh Kumar  Koraon (Sc) + Prayagraj
# 8                  Raj Mani  Koraon (Sc) + Prayagraj
# 9                    Jishan           Kalpi + Jalaun
# 10              Rajiv Kumar           Kalpi + Jalaun
# 11           Rohit Tripathi           Kalpi + Jalaun
# 12             Shyam Kishor           Kalpi + Jalaun
# 13           Harish Chandra  Koraon (Sc) + Prayagraj
# 14                   Sundar           Kalpi + Jalaun
# 15                 Umakanti           Kalpi + Jalaun
# 16  Veerendra Singh Parihar           Kalpi + Jalaun
# 17         Vinod Chaturvedi           Kalpi + Jalaun
# 18                Balak Ram       Orai (Sc) + Jalaun
# 19           Ch. Lachchiram       Orai (Sc) + Jalaun
# 20              Chandrabhan       Orai (Sc) + Jalaun
# 21                Dal Singh       Orai (Sc) + Jalaun
# 22                Rambihari      Madhaugarh + Jalaun
# 23                   Ram Ji      Madhaugarh + Jalaun
# 24  Raghvendra Pratap Singh      Madhaugarh + Jalaun
#
#                            Party              Education  Criminal Cases
# 0                            IND               Graduate               0
# 1                            IND              12th Pass               0
# 2                            BSP          Post Graduate               0
# 3                            INC  Graduate Professional               0
# 4                            IND              10th Pass               0
# 5                            IND              10th Pass               0
# 6                            IND               Literate               0
# 7   Sanatan Sanskriti Raksha Dal              12th Pass               0
# 8                            BJP          Post Graduate               0
# 9              Jan Adhikar Party              12th Pass               0
# 10                    CPI(ML)(L)              10th Pass               0
# 11    Rashtrawadi Party of India          Post Graduate               0
# 12                           IND                 Others               0
# 13                           AAP              12th Pass               0
# 14                           IND              12th Pass               0
# 15                           INC               Literate               0
# 16           Rashtriya Jan Manch               Graduate               0
# 17                            SP          Post Graduate               0
# 18             Jan Adhikar Party               Graduate               0
# 19       RASHTRIYA VIKLANG PARTY               8th Pass               0
# 20                           IND               8th Pass               0
# 21                           IND               Graduate               0
# 22                           IND               8th Pass               0
# 23                           AAP              12th Pass               0
# 24                            SP          Post Graduate               0

# %%
criminal_data_asc.groupby("Party").aggregate(np.sum).sort_values("Criminal Cases",ascending=False).head(25).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Party'>

# %%
asset_data = data[["Candidate","Constituency","Party", "Total Assets"]].sort_values('Total Assets', ascending=False).head(25)
asset_data = asset_data.reset_index(drop=True)
asset_data
# Out:
#                     Candidate                 Constituency  \
# 0        Nawab Kazim Ali Khan              Rampur + Rampur
# 1    Shah Alam (Guddu Jamali)        Mubarakpur + Azamgarh
# 2                Supriya Aron   Bareilly Cantt. + Bareilly
# 3                Amit Agarwal       Meerut Cantt. + Meerut
# 4             Devender Nagpal      Naugawan Sadat + Amroha
# 5                  S.K.Sharma            Mathura + Mathura
# 6                 Rahul Yadav    Sikandrabad + Bulandsahar
# 7                 Kunal Singh            Sahaswan + Budaun
# 8       Sahender Singh Ramala         Chhaprauli + Baghpat
# 9                  Rais Ahmad              Badaun + Budaun
# 10        Yashpal Singh Yadav              Babina + Jhansi
# 11                Ajay Kapoor  Kidwai Nagar + Kanpur Nagar
# 12              Vinay Shankar        Chillupar + Gorakhpur
# 13              Rakesh Pandey    Jalalpur + Ambedkar Nagar
# 14       Kartar Singh Bhadana     Khatauli + Muzaffarnagar
# 15                 Mohd Nasir  Moradabad Rural + Moradabad
# 16      Rani Pakshalika Singh                   Bah + Agra
# 17  Mayankeshwar Sharan Singh               Tiloi + Amethi
# 18               Rajiv Bakshi       Lucknow West + Lucknow
# 19           Umashankar Singh               Rasara + Balia
# 20          Anoop Kumar Gupta             Maholi + Sitapur
# 21     Sindhuja Mishra Senani           Kunda + Pratapgarh
# 22            Dr.Sanjay Singh              Amethi + Amethi
# 23     Raja Bharatendra Singh           Najibabad + Bijnor
# 24           Ajay Kumar Singh    Chauri-Chaura + Gorakhpur
#
#                                      Party  Total Assets
# 0                                      INC    2968848840
# 1   All India Majlis-E-Ittehadul Muslimeen    1958570465
# 2                                       SP    1573049919
# 3                                      BJP    1487664557
# 4                                      BJP    1407648765
# 5                                      BSP    1122970707
# 6                                       SP    1006302500
# 7                 Rashtriya Parivartan Dal     880892909
# 8                                      BJP     845070499
# 9                                       SP     730221928
# 10                                      SP     707404691
# 11                                     INC     694617271
# 12                                      SP     675228964
# 13                                      SP     634647716
# 14                                     BSP     608746125
# 15                                      SP     606821671
# 16                                     BJP     584850043
# 17                                     BJP     580703047
# 18                                     AAP     566207026
# 19                                     BSP     540504522
# 20                                      SP     523943856
# 21                                     BJP     522036165
# 22                                     BJP     504828241
# 23                                     BJP     486025676
# 24                                     IND     485468075

# %%
asset_data.groupby("Party").aggregate(np.sum).sort_values("Total Assets",ascending=False).head(25).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Party'>
