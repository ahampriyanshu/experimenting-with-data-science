# %% [markdown]
# # EDA of Punjab 2022
#
# * [myneta.info](https://myneta.info/)

# %% [markdown]
# ## Extracting data

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from tabulate import tabulate


def inr_to_int(text):
    try:
        text = text.split()
        text = text[1].replace(",", "")
    except:
        return 0
    return int(text)


def main():
    header = ["Candidate", "Party", "Criminal Cases", "Education", "Age", "Constituency",  "Total Assets", "Liabilities"]
    data = []
    constituencies = 0
    candidates = 0
    for i in range(1, 80):
        try:
            print("Trying ID", i, end = ' => ')
            url = "https://myneta.info/uttarakhand2022/index.php?action=show_candidates&constituency_id=" + str(i)
            html = urlopen(url)
            soup = BeautifulSoup(html,'html.parser')
            title = soup.title.text
            title = title.split()
            title = title[4:-2]
            title = " ".join(title)
            title = title.title()
            title = title.split(":")
            constituency = "+".join(title)
            title = ",".join(title)
            print("Saving", title, end = ' => ')
            table = soup.find("table", {"id": "table1"})
            rows = table.find_all('tr')
            total_rows = len(rows)
            for i in range(1, total_rows):
                col_data = []
                cols = rows[i].find_all('td')
                total_cols = len(cols)
                for i in range(0, 5):
                    col_data.append(cols[i].text)
                col_data.append(constituency)
                for i in range(5, total_cols):
                    col_data.append(inr_to_int(cols[i].text))                        
                data.append(col_data)
                candidates += 1
        except :
            print('ERROR')
        else:
            constituencies += 1
            print('SUCCESS')
    df = pd.DataFrame(data = data, columns = header)
    print('Saved =>', candidates, "candidates from", constituencies, "constituencies")
    df.to_csv('uk.csv', index=False)
    

main()
# Out:
# Trying ID 1 => Saving Dwarahat , Almora => SUCCESS
# Trying ID 2 => Saving Salt , Almora => SUCCESS
# Trying ID 3 => Saving Ranikhet , Almora => SUCCESS
# Trying ID 4 => Saving Someshwar (Sc) , Almora => SUCCESS
# Trying ID 5 => Saving Almora , Almora => SUCCESS
# Trying ID 6 => Saving Jageshwar , Almora => SUCCESS
# Trying ID 7 => Saving Kapkote , Bageshwar => SUCCESS
# Trying ID 8 => Saving Bageshwar (Sc) , Bageshwar => SUCCESS
# Trying ID 9 => Saving Badrinath , Chamoli => SUCCESS
# Trying ID 10 => Saving Tharali (Sc) , Chamoli => SUCCESS
# Trying ID 11 => Saving Karanprayag , Chamoli => SUCCESS
# Trying ID 12 => Saving Lohaghat , Champawat => SUCCESS
# Trying ID 13 => Saving Champawat , Champawat => SUCCESS
# Trying ID 14 => Saving Chakrata (St) , Dehradun => SUCCESS
# Trying ID 15 => Saving Vikasnagar , Dehradun => SUCCESS
# Trying ID 16 => Saving Sahaspur , Dehradun => SUCCESS
# Trying ID 17 => Saving Dharampur , Dehradun => SUCCESS
# Trying ID 18 => Saving Raipur , Dehradun => SUCCESS
# Trying ID 19 => Saving Rajpur Road (Sc) , Dehradun => SUCCESS
# Trying ID 20 => Saving Dehradun Cantonment , Dehradun => SUCCESS
# Trying ID 21 => Saving Mussoorie , Dehradun => SUCCESS
# Trying ID 22 => Saving Doiwala , Dehradun => SUCCESS
# Trying ID 23 => Saving Rishikesh , Dehradun => SUCCESS
# Trying ID 24 => Saving  => ERROR
# Trying ID 25 => Saving Haridwar , Haridwar => SUCCESS
# Trying ID 26 => Saving B.H.E.L. Ranipur , Haridwar => SUCCESS
# Trying ID 27 => Saving Jwalapur (Sc) , Haridwar => SUCCESS
# Trying ID 28 => Saving Bhagwanpur(Sc) , Haridwar => SUCCESS
# Trying ID 29 => Saving Jhabrera (Sc) , Haridwar => SUCCESS
# Trying ID 30 => Saving Pirankaliyar , Haridwar => SUCCESS
# Trying ID 31 => Saving Roorkee , Haridwar => SUCCESS
# Trying ID 32 => Saving Khanpur , Haridwar => SUCCESS
# Trying ID 33 => Saving Manglore , Haridwar => SUCCESS
# Trying ID 34 => Saving Laksar , Haridwar => SUCCESS
# Trying ID 35 => Saving Haridwar Rural , Haridwar => SUCCESS
# Trying ID 36 => Saving  => ERROR
# Trying ID 37 => Saving Lalkuan , Nainital => SUCCESS
# Trying ID 38 => Saving Bhimtal , Nainital => SUCCESS
# Trying ID 39 => Saving Nainital(Sc) , Nainital => SUCCESS
# Trying ID 40 => Saving Haldwani , Nainital => SUCCESS
# Trying ID 41 => Saving Kaladhungi , Nainital => SUCCESS
# Trying ID 42 => Saving Ramnagar , Nainital => SUCCESS
# Trying ID 43 => Saving Yamkeshwar , Pauri Garhwal => SUCCESS
# Trying ID 44 => Saving Pauri (Sc) , Pauri Garhwal => SUCCESS
# Trying ID 45 => Saving Srinagar , Pauri Garhwal => SUCCESS
# Trying ID 46 => Saving Chaubattakhal , Pauri Garhwal => SUCCESS
# Trying ID 47 => Saving Lansdowne , Pauri Garhwal => SUCCESS
# Trying ID 48 => Saving Kotdwar , Pauri Garhwal => SUCCESS
# Trying ID 49 => Saving Dharchula , Pithoragarh => SUCCESS
# Trying ID 50 => Saving Didihat , Pithoragarh => SUCCESS
# Trying ID 51 => Saving Pithoragarh , Pithoragarh => SUCCESS
# Trying ID 52 => Saving Gangolihat (Sc) , Pithoragarh => SUCCESS
# Trying ID 53 => Saving Kedarnath , Rudraprayag => SUCCESS
# Trying ID 54 => Saving Rudraprayag , Rudraprayag => SUCCESS
# Trying ID 55 => Saving Ghanshali (Sc) , Tehri Garhwal => SUCCESS
# Trying ID 56 => Saving Devprayag , Tehri Garhwal => SUCCESS
# Trying ID 57 => Saving Narendranagar , Tehri Garhwal => SUCCESS
# Trying ID 58 => Saving Pratapnagar , Tehri Garhwal => SUCCESS
# Trying ID 59 => Saving Tehri , Tehri Garhwal => SUCCESS
# Trying ID 60 => Saving Dhanolti , Tehri Garhwal => SUCCESS
# Trying ID 61 => Saving Jaspur , Udham Singh Nagar => SUCCESS
# Trying ID 62 => Saving Kashipur , Udham Singh Nagar => SUCCESS
# Trying ID 63 => Saving Bajpur (Sc) , Udham Singh Nagar => SUCCESS
# Trying ID 64 => Saving Gadarpur , Udham Singh Nagar => SUCCESS
# Trying ID 65 => Saving Rudrapur , Udham Singh Nagar => SUCCESS
# Trying ID 66 => Saving Kichha , Udham Singh Nagar => SUCCESS
# Trying ID 67 => Saving Sitarganj , Udham Singh Nagar => SUCCESS
# Trying ID 68 => Saving Nanakmatta (St) , Udham Singh Nagar => SUCCESS
# Trying ID 69 => Saving Khatima , Udham Singh Nagar => SUCCESS
# Trying ID 70 => Saving Purola (Sc) , Uttarkashi => SUCCESS
# Trying ID 71 => Saving Yamunotri , Uttarkashi => SUCCESS
# Trying ID 72 => Saving Gangotri , Uttarkashi => SUCCESS
# Trying ID 73 => Saving  => ERROR
# Trying ID 74 => Saving  => ERROR
# Trying ID 75 => Saving  => ERROR
# Trying ID 76 => Saving  => ERROR
# Trying ID 77 => Saving  => ERROR
# Trying ID 78 => Saving  => ERROR
# Trying ID 79 => Saving  => ERROR
# Saved => 626 candidates from 70 constituencies
