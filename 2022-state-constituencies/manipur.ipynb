# %% [markdown]
# # EDA of Manipur 2022
#
# * [myneta.info](https://myneta.info/)

# %% [markdown]
# ## Extracting data

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from tabulate import tabulate


def inr_to_int(text):
    try:
        text = text.split()
        text = text[1].replace(",", "")
    except:
        return 0
    return int(text)


def main():
    header = ["Candidate", "Party", "Criminal Cases", "Education", "Age", "Constituency",  "Total Assets", "Liabilities"]
    data = []
    constituencies = 0
    candidates = 0
    for i in range(1, 70):
        try:
            print("Trying ID", i, end = ' => ')
            url = "https://myneta.info/manipur2022/index.php?action=show_candidates&constituency_id=" + str(i)
            html = urlopen(url)
            soup = BeautifulSoup(html,'html.parser')
            title = soup.title.text
            title = title.split()
            title = title[4:-2]
            title = " ".join(title)
            title = title.title()
            title = title.split(":")
            constituency = "+".join(title)
            title = ",".join(title)
            print("Saving", title, end = ' => ')
            table = soup.find("table", {"id": "table1"})
            rows = table.find_all('tr')
            total_rows = len(rows)
            for i in range(1, total_rows):
                col_data = []
                cols = rows[i].find_all('td')
                total_cols = len(cols)
                for i in range(0, 5):
                    col_data.append(cols[i].text)
                col_data.append(constituency)
                for i in range(5, total_cols):
                    col_data.append(inr_to_int(cols[i].text))                        
                data.append(col_data)
                candidates += 1
        except :
            print('ERROR')
        else:
            constituencies += 1
            print('SUCCESS')
    df = pd.DataFrame(data = data, columns = header)
    print('Saved =>', candidates, "candidates from", constituencies, "constituencies")
    df.to_csv('manipur.csv', index=False)
    

main()
# Out:
# Trying ID 1 => Saving Kumbi , Bishnupur => SUCCESS
# Trying ID 2 => Saving Thanga , Bishnupur => SUCCESS
# Trying ID 3 => Saving Moirang , Bishnupur => SUCCESS
# Trying ID 4 => Saving Bishenpur , Bishnupur => SUCCESS
# Trying ID 5 => Saving Oinam , Bishnupur => SUCCESS
# Trying ID 6 => Saving Nambol , Bishnupur => SUCCESS
# Trying ID 7 => Saving Tengnoupal (St) , Chandel => SUCCESS
# Trying ID 8 => Saving Chandel (St) , Chandel => SUCCESS
# Trying ID 9 => Saving Singhat (St) , Churachandpur => SUCCESS
# Trying ID 10 => Saving Saikot (St) , Churachandpur => SUCCESS
# Trying ID 11 => Saving Churachandpur (St) , Churachandpur => SUCCESS
# Trying ID 12 => Saving Henglep (St) , Churachandpur => SUCCESS
# Trying ID 13 => Saving Thanlon (St) , Churachandpur => SUCCESS
# Trying ID 14 => Saving Tipaimukh (St) , Churachandpur => SUCCESS
# Trying ID 15 => Saving Lamlai , Imphal East => SUCCESS
# Trying ID 16 => Saving Andro , Imphal East => SUCCESS
# Trying ID 17 => Saving Keirao , Imphal East => SUCCESS
# Trying ID 18 => Saving Thongju , Imphal East => SUCCESS
# Trying ID 19 => Saving Khetrigao , Imphal East => SUCCESS
# Trying ID 20 => Saving Khurai , Imphal East => SUCCESS
# Trying ID 21 => Saving Heingang , Imphal East => SUCCESS
# Trying ID 22 => Saving Wangkhei , Imphal East => SUCCESS
# Trying ID 23 => Saving Yaiskul , Imphal East => SUCCESS
# Trying ID 24 => Saving Khundrakpam , Imphal East => SUCCESS
# Trying ID 25 => Saving  => ERROR
# Trying ID 26 => Saving Thangmeiband , Imphal West => SUCCESS
# Trying ID 27 => Saving Mayang Imphal , Imphal West => SUCCESS
# Trying ID 28 => Saving Wangoi , Imphal West => SUCCESS
# Trying ID 29 => Saving Naoria Pakhanglakpa , Imphal West => SUCCESS
# Trying ID 30 => Saving Langthabal , Imphal West => SUCCESS
# Trying ID 31 => Saving Patsoi , Imphal West => SUCCESS
# Trying ID 32 => Saving Konthoujam , Imphal West => SUCCESS
# Trying ID 33 => Saving Lamsang , Imphal West => SUCCESS
# Trying ID 34 => Saving Sekmai (Sc) , Imphal West => SUCCESS
# Trying ID 35 => Saving Singjamei , Imphal West => SUCCESS
# Trying ID 36 => Saving Keisamthong , Imphal West => SUCCESS
# Trying ID 37 => Saving Sagolband , Imphal West => SUCCESS
# Trying ID 38 => Saving Uripok , Imphal West => SUCCESS
# Trying ID 39 => Saving  => ERROR
# Trying ID 40 => Saving Jiribam , Jiribam => SUCCESS
# Trying ID 41 => Saving Saitu (St) , Kangpokpi => SUCCESS
# Trying ID 42 => Saving Kangpokpi , Kangpokpi => SUCCESS
# Trying ID 43 => Saving Saikul (St) , Kangpokpi => SUCCESS
# Trying ID 44 => Saving Tadubi (St) , Senapati => SUCCESS
# Trying ID 45 => Saving Mao (St) , Senapati => SUCCESS
# Trying ID 46 => Saving Karong (St) , Senapati => SUCCESS
# Trying ID 47 => Saving Nungba (St) , Tamenglong => SUCCESS
# Trying ID 48 => Saving Tamenglong (St) , Tamenglong => SUCCESS
# Trying ID 49 => Saving Tamei (St) , Tamenglong => SUCCESS
# Trying ID 50 => Saving Sugnoo , Thoubal => SUCCESS
# Trying ID 51 => Saving Hiyanglam , Thoubal => SUCCESS
# Trying ID 52 => Saving Kakching , Thoubal => SUCCESS
# Trying ID 53 => Saving Wabgai , Thoubal => SUCCESS
# Trying ID 54 => Saving Khangabok , Thoubal => SUCCESS
# Trying ID 55 => Saving Wangjing Tentha , Thoubal => SUCCESS
# Trying ID 56 => Saving Heirok , Thoubal => SUCCESS
# Trying ID 57 => Saving Wangkhem , Thoubal => SUCCESS
# Trying ID 58 => Saving Thoubal , Thoubal => SUCCESS
# Trying ID 59 => Saving Lilong , Thoubal => SUCCESS
# Trying ID 60 => Saving  => ERROR
# Trying ID 61 => Saving Chingai (St) , Ukhrul => SUCCESS
# Trying ID 62 => Saving Ukhrul (St) , Ukhrul => SUCCESS
# Trying ID 63 => Saving Phungyar (St) , Ukhrul => SUCCESS
# Trying ID 64 => Saving  => ERROR
# Trying ID 65 => Saving  => ERROR
# Trying ID 66 => Saving  => ERROR
# Trying ID 67 => Saving  => ERROR
# Trying ID 68 => Saving  => ERROR
# Trying ID 69 => Saving  => ERROR
# Saved => 265 candidates from 60 constituencies
