# %% [markdown]
# # EDA of Goa 2022
#
# * [myneta.info](https://myneta.info/)

# %% [markdown]
# ## Extracting data

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from tabulate import tabulate


def inr_to_int(text):
    try:
        text = text.split()
        text = text[1].replace(",", "")
    except:
        return 0
    return int(text)


def main():
    header = ["Candidate", "Party", "Criminal Cases", "Education", "Age", "Constituency",  "Total Assets", "Liabilities"]
    data = []
    constituencies = 0
    candidates = 0
    for i in range(1, 50):
        try:
            print("Trying ID", i, end = ' => ')
            url = "https://myneta.info/goa2022/index.php?action=show_candidates&constituency_id=" + str(i)
            html = urlopen(url)
            soup = BeautifulSoup(html,'html.parser')
            title = soup.title.text
            title = title.split()
            title = title[4:-2]
            title = " ".join(title)
            title = title.title()
            title = title.split(":")
            constituency = "+".join(title)
            title = ",".join(title)
            print("Saving", title, end = ' => ')
            table = soup.find("table", {"id": "table1"})
            rows = table.find_all('tr')
            total_rows = len(rows)
            for i in range(1, total_rows):
                col_data = []
                cols = rows[i].find_all('td')
                total_cols = len(cols)
                for i in range(0, 5):
                    col_data.append(cols[i].text)
                col_data.append(constituency)
                for i in range(5, total_cols):
                    col_data.append(inr_to_int(cols[i].text))                        
                data.append(col_data)
                candidates += 1
        except :
            print('ERROR')
        else:
            constituencies += 1
            print('SUCCESS')
    df = pd.DataFrame(data = data, columns = header)
    print('Saved =>', candidates, "candidates from", constituencies, "constituencies")
    df.to_csv('goa.csv', index=False)
    

main()
# Out:
# Trying ID 1 => Saving Mandrem , North Goa => SUCCESS
# Trying ID 2 => Saving Pernem (Sc) , North Goa => SUCCESS
# Trying ID 3 => Saving Bicholim , North Goa => SUCCESS
# Trying ID 4 => Saving Tivim , North Goa => SUCCESS
# Trying ID 5 => Saving Mapusa , North Goa => SUCCESS
# Trying ID 6 => Saving Siolim , North Goa => SUCCESS
# Trying ID 7 => Saving Saligao , North Goa => SUCCESS
# Trying ID 8 => Saving Calangute , North Goa => SUCCESS
# Trying ID 9 => Saving Porvorim , North Goa => SUCCESS
# Trying ID 10 => Saving Aldona , North Goa => SUCCESS
# Trying ID 11 => Saving Panaji , North Goa => SUCCESS
# Trying ID 12 => Saving Taleigao , North Goa => SUCCESS
# Trying ID 13 => Saving St. Cruz , North Goa => SUCCESS
# Trying ID 14 => Saving St. Andre , North Goa => SUCCESS
# Trying ID 15 => Saving  => ERROR
# Trying ID 16 => Saving Cumbarjua , North Goa => SUCCESS
# Trying ID 17 => Saving Maem , North Goa => SUCCESS
# Trying ID 18 => Saving Sanquelim , North Goa => SUCCESS
# Trying ID 19 => Saving Poriem , North Goa => SUCCESS
# Trying ID 20 => Saving Valpoi , North Goa => SUCCESS
# Trying ID 21 => Saving Priol , South Goa => SUCCESS
# Trying ID 22 => Saving Ponda , South Goa => SUCCESS
# Trying ID 23 => Saving Siroda , South Goa => SUCCESS
# Trying ID 24 => Saving Marcaim , South Goa => SUCCESS
# Trying ID 25 => Saving Mormugao , South Goa => SUCCESS
# Trying ID 26 => Saving Vasco-Da-Gama , South Goa => SUCCESS
# Trying ID 27 => Saving Dabolim , South Goa => SUCCESS
# Trying ID 28 => Saving Cortalim , South Goa => SUCCESS
# Trying ID 29 => Saving Nuvem , South Goa => SUCCESS
# Trying ID 30 => Saving Curtorim , South Goa => SUCCESS
# Trying ID 31 => Saving Fatorda , South Goa => SUCCESS
# Trying ID 32 => Saving Margao , South Goa => SUCCESS
# Trying ID 33 => Saving Benaulim , South Goa => SUCCESS
# Trying ID 34 => Saving Navelim , South Goa => SUCCESS
# Trying ID 35 => Saving  => ERROR
# Trying ID 36 => Saving Cuncolim , South Goa => SUCCESS
# Trying ID 37 => Saving Velim , South Goa => SUCCESS
# Trying ID 38 => Saving Quepem , South Goa => SUCCESS
# Trying ID 39 => Saving Curchorem , South Goa => SUCCESS
# Trying ID 40 => Saving Sanvordem , South Goa => SUCCESS
# Trying ID 41 => Saving Sanguem , South Goa => SUCCESS
# Trying ID 42 => Saving Canacona , South Goa => SUCCESS
# Trying ID 43 => Saving  => ERROR
# Trying ID 44 => Saving  => ERROR
# Trying ID 45 => Saving  => ERROR
# Trying ID 46 => Saving  => ERROR
# Trying ID 47 => Saving  => ERROR
# Trying ID 48 => Saving  => ERROR
# Trying ID 49 => Saving  => ERROR
# Saved => 301 candidates from 40 constituencies
